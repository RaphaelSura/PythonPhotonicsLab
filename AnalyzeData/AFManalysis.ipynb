# %%
import sys
sys.path.append("..")
import matplotlib
# %matplotlib notebook
import matplotlib.pyplot as plt
from LowLevelModules.AsylumAFM import AFMdata
import seaborn as sb
sb.set_style("ticks")
sb.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %%
# user input
wdir = r'C:\Users\Raphael\OneDrive - Cornell University\TMDs\Sample characterization\AFM\20190701 - Man2403 doestest'
filename = 'scan0006'

# plot everything
file = wdir + '\\' + filename + '.ibw'
try:
    del scan
except:
    pass
scan = AFMdata(file)
scan.plot2D('height')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
# %matplotlib notebook
scan.plot3D('height')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
scan.fig1.savefig(wdir + '\\' + filename + '_heightscan' + '.png', format='png', bbox_inches='tight')
#scan.fig1.savefig(wdir + '\\' + filename + '_ampscan' + '.png', format='png', bbox_inches='tight')
#scan.fig2.savefig(wdir + '\\' + filename + '_heightscan3D' + '.png', format='png', bbox_inches='tight')

# %%
linecut_param = {'pos': -3.01, 'axis': 'Y', 'tilt': 0.4, 'shift': 2, 'case': 'height'}
scan.line_cut(**linecut_param)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
#Run this to save the plots
scan.fig3.savefig(wdir + '\\' + filename + '_linecut' + linecut_param['axis'] + str(linecut_param['pos']) + '.png', format='png', bbox_inches='tight')
#scan.fig3.savefig(wdir + '\\' + filename + '_linecut_zoom' + linecut_param['axis'] + str(linecut_param['pos']) + '.png', format='png', bbox_inches='tight')

# %%
import numpy as np
np.round(scan.Y, 2)
# Out:
# array([-3.38, -3.36, -3.33, -3.3 , -3.28, -3.25, -3.22, -3.2 , -3.17,
#        -3.14, -3.12, -3.09, -3.06, -3.04, -3.01, -2.99, -2.96, -2.93,
#        -2.91, -2.88, -2.85, -2.83, -2.8 , -2.77, -2.75, -2.72, -2.69,
#        -2.67, -2.64, -2.61, -2.59, -2.56, -2.53, -2.51, -2.48, -2.45,
#        -2.43, -2.4 , -2.37, -2.35, -2.32, -2.3 , -2.27, -2.24, -2.22,
#        -2.19, -2.16, -2.14, -2.11, -2.08, -2.06, -2.03, -2.  , -1.98,
#        -1.95, -1.92, -1.9 , -1.87, -1.84, -1.82, -1.79, -1.76, -1.74,
#        -1.71, -1.68, -1.66, -1.63, -1.61, -1.58, -1.55, -1.53, -1.5 ,
#        -1.47, -1.45, -1.42, -1.39, -1.37, -1.34, -1.31, -1.29, -1.26,
#        -1.23, -1.21, -1.18, -1.15, -1.13, -1.1 , -1.07, -1.05, -1.02,
#        -1.  , -0.97, -0.94, -0.92, -0.89, -0.86, -0.84, -0.81, -0.78,
#        -0.76, -0.73, -0.7 , -0.68, -0.65, -0.62, -0.6 , -0.57, -0.54,
#        -0.52, -0.49, -0.46, -0.44, -0.41, -0.38, -0.36, -0.33, -0.31,
#        -0.28, -0.25, -0.23, -0.2 , -0.17, -0.15, -0.12, -0.09, -0.07,
#        -0.04, -0.01,  0.01,  0.04,  0.07,  0.09,  0.12,  0.15,  0.17,
#         0.2 ,  0.23,  0.25,  0.28,  0.31,  0.33,  0.36,  0.38,  0.41,
#         0.44,  0.46,  0.49,  0.52,  0.54,  0.57,  0.6 ,  0.62,  0.65,
#         0.68,  0.7 ,  0.73,  0.76,  0.78,  0.81,  0.84,  0.86,  0.89,
#         0.92,  0.94,  0.97,  1.  ,  1.02,  1.05,  1.07,  1.1 ,  1.13,
#         1.15,  1.18,  1.21,  1.23,  1.26,  1.29,  1.31,  1.34,  1.37,
#         1.39,  1.42,  1.45,  1.47,  1.5 ,  1.53,  1.55,  1.58,  1.61,
#         1.63,  1.66,  1.68,  1.71,  1.74,  1.76,  1.79,  1.82,  1.84,
#         1.87,  1.9 ,  1.92,  1.95,  1.98,  2.  ,  2.03,  2.06,  2.08,
#         2.11,  2.14,  2.16,  2.19,  2.22,  2.24,  2.27,  2.3 ,  2.32,
#         2.35,  2.37,  2.4 ,  2.43,  2.45,  2.48,  2.51,  2.53,  2.56,
#         2.59,  2.61,  2.64,  2.67,  2.69,  2.72,  2.75,  2.77,  2.8 ,
#         2.83,  2.85,  2.88,  2.91,  2.93,  2.96,  2.99,  3.01,  3.04,
#         3.06,  3.09,  3.12,  3.14,  3.17,  3.2 ,  3.22,  3.25,  3.28,
#         3.3 ,  3.33,  3.36,  3.38])
