# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
# %matplotlib notebook
from AFManalysis import AFMdata
from general_functions import get_work_dir
wdir = get_work_dir()

# user input
wdir += r'\TMDs\Sample characterization\AFM\20181214 - AFM hBN and WSe2 on nanopillars'
filename = 'scan0003'

# plot everything
file = wdir + '\\' + filename + '.ibw'
try:
    del scan
except:
    pass
scan = AFMdata(file)
scan.plot2D('height')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
# %matplotlib notebook
scan.plot3D()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
scan.fig1.savefig(wdir + '\\' + filename + '_heightscan' + '.png', format='png', bbox_inches='tight')
#scan.fig2.savefig(wdir + '\\' + filename + '_heightscan3D' + '.png', format='png', bbox_inches='tight')

# %%
linecut_param = {'pos': 1.03, 'axis': 'Y', 'tilt': -6, 'shift': -13, 'case': 'height'}
scan.line_cut(**linecut_param)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
#Run this to save the plots
scan.fig3.savefig(wdir + '\\' + filename + '_linecut' + linecut_param['axis'] + str(linecut_param['pos']) + '.png', format='png', bbox_inches='tight')

# %%
scan.X
# Out:
# array([-10.        ,  -9.92156863,  -9.84313725,  -9.76470588,
#         -9.68627451,  -9.60784314,  -9.52941176,  -9.45098039,
#         -9.37254902,  -9.29411765,  -9.21568627,  -9.1372549 ,
#         -9.05882353,  -8.98039216,  -8.90196078,  -8.82352941,
#         -8.74509804,  -8.66666667,  -8.58823529,  -8.50980392,
#         -8.43137255,  -8.35294118,  -8.2745098 ,  -8.19607843,
#         -8.11764706,  -8.03921569,  -7.96078431,  -7.88235294,
#         -7.80392157,  -7.7254902 ,  -7.64705882,  -7.56862745,
#         -7.49019608,  -7.41176471,  -7.33333333,  -7.25490196,
#         -7.17647059,  -7.09803922,  -7.01960784,  -6.94117647,
#         -6.8627451 ,  -6.78431373,  -6.70588235,  -6.62745098,
#         -6.54901961,  -6.47058824,  -6.39215686,  -6.31372549,
#         -6.23529412,  -6.15686275,  -6.07843137,  -6.        ,
#         -5.92156863,  -5.84313725,  -5.76470588,  -5.68627451,
#         -5.60784314,  -5.52941176,  -5.45098039,  -5.37254902,
# ...
