# %%
import sys
sys.path.append("..")
import matplotlib
# %matplotlib notebook
import matplotlib.pyplot as plt
from LowLevelModules.AsylumAFM import AFMdata
import seaborn as sb
sb.set_style("ticks")
sb.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

# %%
# user input
wdir = r'C:\Users\Raphael\OneDrive - Cornell University\TMDs\Sample characterization\AFM\20190809 - WSe2 hBN drum device'
filename = 'scan0001'

# plot everything
file = wdir + '\\' + filename + '.ibw'
try:
    del scan
except:
    pass
scan = AFMdata(file, rotate=3)
scan.plot2D('height')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
# %matplotlib notebook
scan.plot3D('height')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
scan.fig1.savefig(wdir + '\\' + filename + '_heightscan' + '.png', format='png', bbox_inches='tight')
#scan.fig1.savefig(wdir + '\\' + filename + '_ampscan' + '.png', format='png', bbox_inches='tight')
#scan.fig2.savefig(wdir + '\\' + filename + '_heightscan3D' + '.png', format='png', bbox_inches='tight')

# %%
linecut_param = {'pos': -3.54, 'axis': 'X', 'tilt': -1, 'shift': 28, 'case': 'height'}
scan.line_cut(**linecut_param)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
#Run this to save the plots
scan.fig3.savefig(wdir + '\\' + filename + '_linecut' + linecut_param['axis'] + str(linecut_param['pos']) + '.png', format='png', bbox_inches='tight')
#scan.fig3.savefig(wdir + '\\' + filename + '_linecut_zoom' + linecut_param['axis'] + str(linecut_param['pos']) + '.png', format='png', bbox_inches='tight')

# %%
import numpy as np
np.round(scan.X, 2)
# Out:
# array([-12.72, -12.62, -12.52, -12.42, -12.32, -12.22, -12.12, -12.02,
#        -11.92, -11.82, -11.72, -11.62, -11.52, -11.42, -11.32, -11.22,
#        -11.12, -11.02, -10.92, -10.82, -10.72, -10.62, -10.52, -10.43,
#        -10.33, -10.23, -10.13, -10.03,  -9.93,  -9.83,  -9.73,  -9.63,
#         -9.53,  -9.43,  -9.33,  -9.23,  -9.13,  -9.03,  -8.93,  -8.83,
#         -8.73,  -8.63,  -8.53,  -8.43,  -8.33,  -8.23,  -8.13,  -8.03,
#         -7.93,  -7.83,  -7.73,  -7.63,  -7.53,  -7.43,  -7.33,  -7.23,
#         -7.13,  -7.03,  -6.93,  -6.83,  -6.73,  -6.63,  -6.53,  -6.43,
#         -6.33,  -6.24,  -6.14,  -6.04,  -5.94,  -5.84,  -5.74,  -5.64,
#         -5.54,  -5.44,  -5.34,  -5.24,  -5.14,  -5.04,  -4.94,  -4.84,
#         -4.74,  -4.64,  -4.54,  -4.44,  -4.34,  -4.24,  -4.14,  -4.04,
#         -3.94,  -3.84,  -3.74,  -3.64,  -3.54,  -3.44,  -3.34,  -3.24,
#         -3.14,  -3.04,  -2.94,  -2.84,  -2.74,  -2.64,  -2.54,  -2.44,
# ...
