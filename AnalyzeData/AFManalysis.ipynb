# %%
import os
import sys
sys.path.append("..")
import matplotlib
# %matplotlib notebook
import matplotlib.pyplot as plt
from LowLevelModules.AsylumAFM import AFMdata
from LowLevelModules.GeneralFunctions import prettify_2d_plot
# import seaborn as sb
import numpy as np
import ipywidgets as widgets
from IPython.display import display
# sb.set_style("ticks")
# sb.set_context("notebook", font_scale=1.5, rc={"lines.linewidth": 2.5})

### USER INPUT ###
wdir = r'Z:\Projects\WSe2\2020\01 january\2020-01-29 AFM data WSe2-hBN sample and hBN wrinkle samples\200115 - WSe2 hBN gated NP devices'
##################

filenames = [f[:-4] for f in os.listdir(wdir) if '.ibw' in f]
file_choice = widgets.RadioButtons(options=filenames,
                                     value=filenames[0],
                                     description='file')
display(file_choice)
# Out:
# RadioButtons(description='file', options=('scan0000', 'scan0001', 'scan0002', 'scan0003', 'scan0004', 'scan000…

# %%
# plot everything
file = wdir + '\\' + file_choice.value + '.ibw'
try:
    del scan
except:
    pass
scan = AFMdata(file, rotate=0)
scan.plot2D('height')
plt.tight_layout()

scan.fig1.savefig(wdir + '\\' + file_choice.value + '_heightscan' + '.png', format='png', bbox_inches='tight')
# Out:
# <img src="data:image/png;base64,..." width="700">

# %%
# %matplotlib notebook
# scan.plot3D('height')

# %%
linecut_param = {'pos': -11.62, 'axis': 'Y', 'tilt': 3.8, 'shift': 0, 'case': 'height'}
scan.line_cut(**linecut_param)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
#Run this to save the plots
scan.fig3.savefig(wdir + '\\' + file_choice.value + '_linecut' + linecut_param['axis'] + str(linecut_param['pos']) + '.png', format='png', bbox_inches='tight')
#scan.fig3.savefig(wdir + '\\' + filename + '_linecut_zoom' + linecut_param['axis'] + str(linecut_param['pos']) + '.png', format='png', bbox_inches='tight')

# %%
import numpy as np
np.round(scan.Y, 2)
# Out:
# array([-12.5 , -12.4 , -12.3 , -12.21, -12.11, -12.01, -11.91, -11.81,
#        -11.72, -11.62, -11.52, -11.42, -11.32, -11.23, -11.13, -11.03,
#        -10.93, -10.83, -10.74, -10.64, -10.54, -10.44, -10.34, -10.25,
#        -10.15, -10.05,  -9.95,  -9.85,  -9.75,  -9.66,  -9.56,  -9.46,
#         -9.36,  -9.26,  -9.17,  -9.07,  -8.97,  -8.87,  -8.77,  -8.68,
#         -8.58,  -8.48,  -8.38,  -8.28,  -8.19,  -8.09,  -7.99,  -7.89,
#         -7.79,  -7.7 ,  -7.6 ,  -7.5 ,  -7.4 ,  -7.3 ,  -7.21,  -7.11,
#         -7.01,  -6.91,  -6.81,  -6.72,  -6.62,  -6.52,  -6.42,  -6.32,
#         -6.23,  -6.13,  -6.03,  -5.93,  -5.83,  -5.74,  -5.64,  -5.54,
#         -5.44,  -5.34,  -5.25,  -5.15,  -5.05,  -4.95,  -4.85,  -4.75,
#         -4.66,  -4.56,  -4.46,  -4.36,  -4.26,  -4.17,  -4.07,  -3.97,
#         -3.87,  -3.77,  -3.68,  -3.58,  -3.48,  -3.38,  -3.28,  -3.19,
#         -3.09,  -2.99,  -2.89,  -2.79,  -2.7 ,  -2.6 ,  -2.5 ,  -2.4 ,
# ...

# %%
scan.signal.shape[2]
# Out:
# 5
