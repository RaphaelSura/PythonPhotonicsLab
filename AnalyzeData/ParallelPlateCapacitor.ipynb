# %%
#Capacitor parallel plate formula C = epsilon * A / d
import numpy as np

vac_perm = 8.85e-12
eps_air = 1 * vac_perm
eps_SiO2 = 15 * vac_perm
r_drum = 2.5e-6
A = np.pi * r_drum**2
d = 250e-9

C = eps_air * A / d
print(f'Capacitance = {C} F')
# Out:
# Capacitance = 6.950773746067418e-16 F

# %%
import matplotlib.pyplot as plt
lambda_0 = 780
n_eff = 2.09
theta_deg = np.arange(0, 45, 1)
theta_rad = theta_deg * np.pi/180
lbd = lambda_0 * np.sqrt(1-(np.sin(theta_rad)/n_eff)**2)
fig, ax = plt.subplots()
plt.plot(theta_deg, lbd)
